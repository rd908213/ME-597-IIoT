# %% [markdown]
# <a href="https://colab.research.google.com/github/purduelamm/purdue_me597_iiot/blob/main/lab/lab5/PL5_Colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prelab 5.1 MTConnect Adapter

# %% [markdown]
# ## Learning Goals
#
# Students will be able to:
#
# 1. Start the MTConnect Adapter to examine contents via localhost.
# 2. Modify code to generate random values for multiple sensors in MTConnect
# 3. Demonstrate knowledge of the MTConnect and XML standards

# %% [markdown]
# ## 1.1 Introduction
#
# In the previous lab (Lab 4), we learned the concept of MTConnect and performed hands-on activities to run MTConnect agents in various MTConnect configurations. By MTConnect adapter simulation, we got to know the data stream from MTConnect adapter to MTConnect agent. In addition, we practiced the client request to MTConnect agent via HTTP request.
#
# The purpose of Lab 5 is 1) to program MTConnect adapters in various configurations and 2) to be familiar with the client application (data collection via HTTP request and XML parsing). In this prelab, we will practice Python programming for MTConnect adapter and XML parsing. However, in Prelab 5, we will mainly practice and understand MTConnect adapter Python programming by generating random data.

# %% [markdown]
# ## 1.2 MTConnect Adapter
#
# In this prelab, we will program a simple Python code to run MTConnect adapter by generating random values without sensors. The schematic of MTConnect configuration is illustrated in Figure 1. The data item configuration is shown in Figure 2.The laptop plays the role of both MTConnect agent and MTConnect adapter. Before we collect data directly from the sensors (ADXL345, DS18B20, and virtual sensor --- there are no physical sensors related to humidity measurement), let’s try to make random values assumed by the sensors as the MTConnect data transmission.
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S25_update/prelab5_fig1.png?raw=true" width="80%">
#
# _Figure 1 MTConnect Schematic_
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S25_update/prelab5_fig2.png?raw=true" width="70%">
#
# _Figure 2 Data item configuration_
#
# For the MTConnect agent, you are able to reuse the complied execution file and other files from Lab 4. It would be better to make copy of the MTConnect agent directory every time rather than modify it every time in the original MTConnect agent. For the MTConnect agent set up, please follow procedure below.
#
# 1. Make the Host IP address and the Port of the _‘Adapter1’_ as _‘127.0.0.1’_ and _‘7878’_, respectively
#
# a. Again, 127.0.0.1 IP address means the machine host itself. That has the same meaning as localhost. Therefore, if you make ‘Host’ as ‘localhost’, it works as well.
#
# b. Also, in the configuration file (_‘agent.cfg’_), The ‘#’ mark in front of the line means comment out the line as Python does. Therefore, MTconnect agent ignores the lines starting with '#'.
#
# c. In this example, the Port number for the agent is 5000. But you can set a different port number.
#
#    <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/prelab5_img1.png?raw=true" width="70%">
#
# 2. Make ‘Device.xml’ as the capture below (the same with Lab4 Task2.3, Task3.2, and Task3.3)
#
#    <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/prelab5_img2.png?raw=true" width="100%">
#
# 3. Save _‘agent.cfg’_ and _‘Device.xml’_
# 4. Run _‘agent.exe’_ on _‘Command Prompt’_
# 5. Check that agent is working using _‘http://127.0.0.1:5000/current’_ or _‘http://localhost:5000/current’_ on a web browser.
#
# **If nothing is shown in your browser, please refer to 'Blank Screen Solution' in Task 2.1 of Lab 4: [L4 Colab 2](https://githubtocolab.com/purduelamm/purdue_me597_iiot/blob/main/lab/lab4/L4_Colab2.ipynb)**
#
# a. Because no adapters are working, the values of all data items are ‘UNAVILABLE’.
#
#    <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/prelab5_img3.png?raw=true" width="60%">

# %% [markdown]
# Now, you are all set for the MTConnect agent part. Keep the agent running. **For the MTConnect adapter<sup>1</sup>, please download [adapter_sample.zip](https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/lab5/adapter_sample.zip?raw=true) to laptop. Extract the zip file. The list on the zip file is below.**
#
# - [adapter_sample.py](https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/lab5/adapter_sample/adapter_sample.py?raw=true)
#   - Sample adapter program for this lab
#   - There are comments on the lines for the hint and usage
# - [data_item.py](https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/lab5/adapter_sample/data_item.py?raw=true)
#   - Data item package for MTConnect (by System Insights)
#   - You do not need to touch this file, but if you are interested in details of program of MTConnect, please take look at it.
# - [mtconnect_adapter.py](https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/lab5/adapter_sample/mtconnect_adapter.py?raw=true)
#   - MTConnect adapter package (by System Insights)
#   - You do not need to touch this file, but if you are interested in details of program of MTConnect, please take look at it.
#
# First, run the sample program (_‘adapter_sample.py’_) and then check _‘current’_ request to the MTConnect agent. The response will look like Figure 3. Because only X-axis acceleration (id = _‘a1’_) and temperature (id = _‘t1’_) values are added as the data items of MTConnect adapter and having the random values, other data items are still showing ‘UNAVAILABLE’. When the MTConnect adapter is made a connection to the agent, the EVENT item id ‘avail’ is changed to ‘AVAILABLE’. In reverse, the MTConnect adapter isn’t made a connection to the agent, it is changed to ‘UNAVAILABLE’. Therefore, by checking the ‘Availability’ (id = ‘avail’) we can see whether the adapter is connected to the agent well or not. If the adapter is connected but the SAMPLE values (sensor data) are not changing, we may consider the issues on the sensor data access. Please note that to halt (forcedly stop) the MTConnect adapter, the shortcut on the terminal is Ctrl + c. And the printing out values is to see what values are transmitting to the agent.
#
#    <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/prelab5_fig3.png?raw=true" width="80%">
#
# _Figure 3 Capture of web browser of ‘current’ request to agent after running sample code_
#
# ---
#
# <sup>1</sup>For this lab, MTConnect adapter based on Python was modified from https://github.com/mtconnect/PocketNC_adapter.

# %% [markdown]
# ### Task 1.1
#
# By modifying the sample code (‘adapter_sample.py’), generate random data streams for remaining data items (id = ‘a2’, ‘a3’, ‘h1’).
#
# - Read the comments in the code.
# - Make sure of the reasonable random value ranges.
#
# Capture your web browser of ‘current’ request to agent after running the code as Figure 4 and attach it to the report below.

# %% [markdown]
# ---
#
# <img src="https://github.com/rd908213/ME-597-IIoT/blob/main/lab/lab5/img/PL5_Task1.1.png?raw=true" width="100%">
#
# ---

# %% [markdown]
#    <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S26_update/Prelab5_fig4.PNG?raw=true" width="90%">
#
# _Figure 4 Capture of web browser of ‘current’ request to agent after running the modified sample code to have all random data_

# %% [markdown]
# ### Task 1.2
#
# It is possible to run two or more MTConnect adapters for an MTConnect agent. Try to split the MTConnect adapter into two adapters according to sensor types as Figure 5 then run both simultaneously. Follow the instructions and hints below.
#
# 1. After performing this task, provide your codes in the code blocks below.
# 2. Provide your _'agent.cfg'_ in the text block below.
# 3. Confirm your adapters are working correctly from the MTConnect agent.
#
# - Split the sample MTConnect Python code into two separate codes.
# - Filenames for the adapters are 'adapter_sample_Task1.2_1.py' and 'adapter_sample_Task1.2_2.py', respectively.
# - Make port numbers be 7878 and 7879, respectively.
# - Make each adapter have a different sampling period by changing time.sleep(t) method in the code. For example, sampling periods are 1 sec and 3 sec, respectively.
# - Hint: You don't need to change _'Device.xml'_.
# - Hint: You have to change _'agent.cfg'_.
# - Hint: You use the same IP address for two adapters.
#
#    <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S25_update/prelab5_fig5.png?raw=true" width="80%">
#
# _Figure 5 MTConnect schematic 2: two MTConnect adapters for an agent_

# %%
### Copy and paste 'adapter_sample_Task1.2_1.py' here

import random
import sys
import time
import datetime
from data_item import Event, Sample  # load data_item package
from mtconnect_adapter import Adapter  # load mtconnect_adapter package


class MTConnectAdapter(object):

    def __init__(self, host, port):
        # MTConnect adapter connection info
        self.host = host
        self.port = port
        self.adapter = Adapter((host, port))

        # For samples
        self.a1 = Sample("a1")  # self.a1 takes 'a1' data item id.
        self.adapter.add_data_item(self.a1)  # adding self.a1 as a data item
        self.a2 = Sample("a2")  # self.a2 takes 'a2' data item id.
        self.adapter.add_data_item(self.a2)  # adding self.a2 as a data item
        self.a3 = Sample("a3")  # self.a3 takes 'a3' data item id.
        self.adapter.add_data_item(self.a3)  # adding self.a3 as a data item
        ## Add more samples below

        # For events
        self.event = Event("event")  # self.event takes 'event' data item name.
        self.adapter.add_data_item(
            self.event
        )  # adding self.event as a data item
        ## Add more events below

        # MTConnnect adapter availability
        self.avail = Event("avail")
        self.adapter.add_data_item(self.avail)

        # Start MTConnect
        self.adapter.start()
        self.adapter.begin_gather()
        self.avail.set_value("AVAILABLE")
        self.adapter.complete_gather()
        self.adapter_stream()

    def adapter_stream(self):
        while True:
            try:
                # Do something here.
                a1 = random.uniform(
                    -1, 1
                )  # this example is to take a random float between -1 and 1.
                a2 = random.uniform(
                    -1, 1
                )  # this example is to take a random float between -1 and 1.
                a3 = random.uniform(
                    -1, 1
                )  # this example is to take a random float between -1 and 1.

                self.adapter.begin_gather()
                self.a1.set_value(
                    str(a1)
                )  # set value of a1 data item, format: str(float)
                self.a2.set_value(
                    str(a2)
                )  # set value of a2 data item, format: str(float)
                self.a3.set_value(
                    str(a3)
                )  # set value of a3 data item, format: str(float)
                self.adapter.complete_gather()

                print(
                    "{} RANDOM VALUE a1={} mm/s^2".format(
                        datetime.datetime.now(), a1
                    )
                )  # printing out datetime now and a1
                print(
                    "{} RANDOM VALUE a2={} mm/s^2".format(
                        datetime.datetime.now(), a2
                    )
                )  # printing out datetime now and a2
                print(
                    "{} RANDOM VALUE a3={} mm/s^2".format(
                        datetime.datetime.now(), a3
                    )
                )  # printing out datetime now and a3
                print(
                    datetime.datetime.now(),
                    "MTConnect data items gathering completed...\n",
                )  # printing out MTConnect data collection is done.

                time.sleep(1)  # wait for 2 seconds

            except KeyboardInterrupt:
                print("Stopping MTConnect...")
                self.adapter.stop()  # Stop adapter thread
                sys.exit()  # Terminate Python


## ====================== MAIN ======================
if __name__ == "__main__":
    print("Starting up!")
    MTConnectAdapter("127.0.0.1", 7878)  # Args: host ip, port number

# %%
### Copy and paste 'adapter_sample_Task1.2_2.py' here

import random
import sys
import time
import datetime
from data_item import Event, Sample  # load data_item package
from mtconnect_adapter import Adapter  # load mtconnect_adapter package


class MTConnectAdapter(object):

    def __init__(self, host, port):
        # MTConnect adapter connection info
        self.host = host
        self.port = port
        self.adapter = Adapter((host, port))

        # For samples
        self.t1 = Sample("t1")  # self.t1 takes 't1' data item id.
        self.adapter.add_data_item(self.t1)  # adding self.t1 as a data item
        self.h1 = Sample("h1")  # self.h1 takes 'h1' data item id.
        self.adapter.add_data_item(self.h1)  # adding self.h1 as a data item
        ## Add more samples below

        # For events
        self.event = Event("event")  # self.event takes 'event' data item name.
        self.adapter.add_data_item(
            self.event
        )  # adding self.event as a data item
        ## Add more events below

        # MTConnnect adapter availability
        self.avail = Event("avail")
        self.adapter.add_data_item(self.avail)

        # Start MTConnect
        self.adapter.start()
        self.adapter.begin_gather()
        self.avail.set_value("AVAILABLE")
        self.adapter.complete_gather()
        self.adapter_stream()

    def adapter_stream(self):
        while True:
            try:
                # Do something here.
                t1 = random.uniform(
                    20, 25
                )  # this example is to take a random float between 15 and 25.
                h1 = random.uniform(
                    40, 60
                )  # this example is to take a random float between 40 and 60.

                self.adapter.begin_gather()
                self.t1.set_value(
                    str(t1)
                )  # set value of t1 data item, format: str(float)
                self.h1.set_value(
                    str(h1)
                )  # set value of h1 data item, format: str(float)
                self.adapter.complete_gather()

                print(
                    "{} RANDOM VALUE t1={} °C".format(
                        datetime.datetime.now(), t1
                    )
                )  # printing out datetime now and t1
                print(
                    "{} RANDOM VALUE h1={} %".format(
                        datetime.datetime.now(), h1
                    )
                )  # printing out datetime now and h1
                print(
                    datetime.datetime.now(),
                    "MTConnect data items gathering completed...\n",
                )  # printing out MTConnect data collection is done.

                time.sleep(3)  # wait for 2 seconds

            except KeyboardInterrupt:
                print("Stopping MTConnect...")
                self.adapter.stop()  # Stop adapter thread
                sys.exit()  # Terminate Python


## ====================== MAIN ======================
if __name__ == "__main__":
    print("Starting up!")
    MTConnectAdapter("127.0.0.1", 7879)  # Args: host ip, port number

# %% [markdown]
# ```ini
# Devices = ./Device.xml
# Port = 5000
# AllowPut = true
# ReconnectInterval = 1000
# BufferSize = 17
# MonitorConfigFiles = true
# Pretty = true
# SchemaVersion = 1.5
#
# Adapters {
#    # Log file has all machines with device name prefixed
#    Adapter1 {
#       Host = 127.0.0.1
#       Port = 7878
#    }
#     Adapter2 {
#       Host = 127.0.0.1
#       Port = 7879
#    }
# }
#
# Files {
#     schemas {
#         Path = ./schemas
#         Location = /schemas/
#     }
#     styles {
#         Path = ./styles
#         Location = /styles/
#     }
#     Favicon {
#         Path = ./styles/favicon.ico
#         Location = /favicon.ico
#     }
# }
#
# StreamsStyle {
#   Location = /styles/Streams.xsl
# }
#
# # Logger Configuration
# logger_config
# {
#     logging_level = debug
#     output = cout
# }
# ```

# %% [markdown]
# ---
#
# <img src="https://github.com/rd908213/ME-597-IIoT/blob/main/lab/lab5/img/PL5_Task1.2.png?raw=true" width="100%">
#
# ---

# %% [markdown]
# ### Additional discussion
#
# In this prelab, we only used a laptop for MTConnect agent as well as adapter. By using the sample adapter code, can you create different configurations for MTConnect? For example, Raspberry Pi is an MTConnect adapter and laptop is an MTConnect agent. Justify and describe how you make the MTConnect architecture below. You can also use figures, pictures, codes, and so on.

# %% [markdown]
# ---
#
# Yes, you can create different configurations for MTConnect. For example, since you can specify a configuration file at runtime, you could have a library full of different agent configurations. When using windows for example:
# ```bash
# agent.exe run agent1.cfg
# ```
# This will specify to use a configuration file named `agent1.cfg`.
#
# You can do the same thing with different adapters by writing separate python files for each adapter and running them in separate command windows. You could also use subprocesses to run different adapters simultaneously or design an adapter two run asynchronously and then run two different instances.
#
# The overall architecture for creating different configurations would be:
#   * Raspberry pi:
#     Run multiple adapters either through subprocesses, separate windows or async programming
#   * Windows:
#     Run multiple agents using different configuration files.
#
# ---

# %% [markdown]
# ## MTConnect Standard
#
# In Lab 5, we will run the MTConnect adapter for each sensor on Raspberry Pi. Please take a look at the PDF document linked below and read the following chapters:
#
# - (Reading) MTConnect® Standard, Part 1.0 – Overview and Fundamentals, Version 1.8.0: https://docs.mtconnect.org/MTConnect_Part_1-0-Overview_and_Fundamentals_1-8-0.pdf
#   - Chapter 6 XML representation of Response Documents
#   - Chapter 7 Protocol and Messaging
#   - Chapter 8 HTTP Messaging Supported by an Agent

# %% [markdown]
# ### Task 1.3
#
# Answer the questions below in response to the MTConnect Standard document above.

# %% [markdown]
# #### 1. Find and provide the time-zone that MTConnect timestamp uses and explain why it is that time-zone.

# %% [markdown]
# ---
#
# The time-zone that MTConnect uses is the UTC/GMT or Coordinated Universal Time/Greenwich Mean Time. MTConnect uses this timestamp because it is the primary time standard by which the world regulates clocks and time.
#
# ---

# %% [markdown]
# #### 2. List the primary components necessary between an MTConnect agent and client application.

# %% [markdown]
# ---
#
# The primary components necessary between an MTConnect Agent and Client application are requests and responses. Client software sends a request to an agent, typically over HTTP. In return, the agent will publish a response document. This response document will include a header and devices element, where the header will define version information, storage capacity and other parameters associated with the agent. The Devices element contains the equipment metadata for example sensor readings.
#
# ---

# %% [markdown]
# #### 3. What is the interface that an MTConnect agent must use, that is supported by HTTP?

# %% [markdown]
# ---
#
# The MTConnect agent uses the REST interface to communicate with client applications. The REST interface supports an Application Programming Interface with which to retrieve data from devices.
#
# ---

# %% [markdown]
# ## XML Parsing and XPath
#
# In Lab 5, we will also explore MTConnect data deeper. For that, we need to know and be familiar with XML parsing and XPath. By using XPath and XML parsing, you can fluently handle the MTConnect request and responded XML documents.
#
# - (Tutorial) XML parsing in Python
#   - GeeksforGeeks: https://www.geeksforgeeks.org/xml-parsing-python/
#   - Python Standard Library: https://docs.python.org/3/library/xml.etree.elementtree.html
# - (Tutorial) XPath
#   - W3Schools: https://www.w3schools.com/xml/xpath_intro.asp

# %% [markdown]
# ### Task 1.4
#
# Answer the questions below in response to the XML content above.

# %% [markdown]
# ### 1. What is XML parsing? Define XML parsing and explain how it works.

# %% [markdown]
# ---
#
# XML parsing is the process of breaking up an XML file into usable objects that another software can use. For example in python, using the python standard library you can extract all of the data contained within an xml file. It works by using parent-child relationships which can be iterated over to extract data. All of the child nodes within a parent tag can be extracted, and the data itself is contained within its attributes.
#
# ---

# %% [markdown]
# ### 2. What is XPath?

# %% [markdown]
# ---
#
# XPath is a way to convert an XML document into a more familiar format of the pathing. It is also a major element in the eXtensible Stylesheet Language Transformation (XSLT) standard. This allows data any XML document to be accessed through simple string expressions. This allows parsers to be built very easily in any language.
#
# ---

# %% [markdown]
# <br></br>
#
# Get back to [Lab Index Page](https://colab.research.google.com/github/purduelamm/purdue_me597_iiot/blob/main/index.ipynb)
